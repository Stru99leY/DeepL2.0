# %%
import torch
print(torch.__version__)
print("Is CUDA enabled?",torch.cuda.is_available())
# Out:
# d:\HUT\BigData\envs\dl\lib\site-packages\torch\nn\modules\transformer.py:20: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# 2.1.0
# Is CUDA enabled? True

# %%
from mxnet import autograd,np,npx

npx.set_np()

x = np.arange(4.0)
x
# Out:
# Traceback (most recent call last):
#
#   File d:\HUT\BigData\envs\dl\lib\site-packages\IPython\core\interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 1
#     from mxnet import autograd,np,npx
#
#   File d:\HUT\BigData\envs\dl\lib\site-packages\mxnet\__init__.py:82
#     from . import gluon
#
#   File d:\HUT\BigData\envs\dl\lib\site-packages\mxnet\gluon\__init__.py:36
#     from . import data
#
#   File d:\HUT\BigData\envs\dl\lib\site-packages\mxnet\gluon\data\__init__.py:26
#     from .dataloader import *
#
#   File d:\HUT\BigData\envs\dl\lib\site-packages\mxnet\gluon\data\dataloader.py:278
#     generator = lambda: [(yield self._batchify_fn([self._dataset[idx] for idx in batch]))
#                         ^
# SyntaxError: 'yield' inside list comprehension
